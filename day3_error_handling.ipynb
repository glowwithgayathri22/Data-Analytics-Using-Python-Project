# %% [markdown]
# <a href="https://colab.research.google.com/github/glowwithgayathri22/Data-Analytics-Using-Python-Project/blob/main/day3_error_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num = int(input("Enter number:"))
  print(num)


except:
  print("Invalid Input")
# Out:
# Enter number:123
# 123

# %%
def attendance(attended, total):
    return (attended / total) * 100

attended = int(input("Classes attended: "))
total = int(input("Total classes: "))

percentage = attendance (attended, total)

print("Attendance Percentage", round (percentage, 2),"%")

if percentage >= 75:
    print("Eligible")

else:
   print("Not Eligible")
# Out:
# Classes attended: 45
# Total classes: 78
# Attendance Percentage 57.69 %
# Not Eligible

# %%
import numpy as np

mark = np.array([90, 85, 78, 92])

print(mark)
# Out:
# [90 85 78 92]

# %%
import numpy as np

student = np.array([
    [90, 85],
    [78, 92],
    [88, 95],
])
print(student)
# Out:
# [[90 85]
#  [78 92]
#  [88 95]]
