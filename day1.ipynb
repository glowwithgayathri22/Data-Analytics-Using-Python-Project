# %% [markdown]
# <a href="https://colab.research.google.com/github/glowwithgayathri22/Data-Analytics-Using-Python-Project/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Mark1 = int(input("Enter Mark 1:"))
Mark2 = int(input("Enter Mark 2:"))
Mark3 = int(input("Enter Mark 3:"))

Total = Mark1 + Mark2 + Mark3
Average = Total/3

print("Total:",Total)
print("Average:",Average)

if Average >=50:
  print("pass")
else:
    print("fail")
# Out:
# Enter Mark 1:30
# Enter Mark 2:80
# Enter Mark 3:55
# Total: 165
# Average: 55.0
# pass
